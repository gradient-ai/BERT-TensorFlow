# %% [markdown]
# # Kaggle instructions
#
# 1. Get a Kaggle account
# 2. Create an API token by going to your Account settings, and save kaggle.json.
# > Note: you may need to create a new api token if you have already created one.
# 3. Upload kaggle.json to this Gradient Notebook
# 4. Either run the cell below or run the following commands in a terminal (this may take a while)
# > Note: Do not share a notebook with your api key enabled

# %%
# !mv kaggle.json ~/.kaggle/
# !pip install kaggle
# !kaggle datasets download snap/amazon-fine-food-reviews
# !unzip amazon-fine-food-reviews.zip

# %% [markdown]
# # Installs and imports
#
# We will also wget a useful script file from the Google BERT repo.

# %%
# !pip install tensorflow_hub
# !pip install tokenization
# !wget https://raw.githubusercontent.com/google-research/bert/master/tokenization.py

# %%
#Importing the essential libraries

import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Activation, Dropout, Flatten
from tensorflow.keras.layers import BatchNormalization, Conv2D, MaxPool2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.callbacks import LearningRateScheduler, TensorBoard
from datetime import datetime
from sklearn.metrics import roc_auc_score
import numpy as np
import pandas as pd
from tqdm import tqdm
import os
import re
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading in the data

# %%
#Read the dataset - Amazon fine food reviews
reviews = pd.read_csv("Reviews.csv")

#check the info of the dataset
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      568454 non-null  int64
#  1   ProductId               568454 non-null  object
#  2   UserId                  568454 non-null  object
#  3   ProfileName             568438 non-null  object
#  4   HelpfulnessNumerator    568454 non-null  int64
#  5   HelpfulnessDenominator  568454 non-null  int64
#  6   Score                   568454 non-null  int64
#  7   Time                    568454 non-null  int64
#  8   Summary                 568427 non-null  object
#  9   Text                    568454 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 43.4+ MB

# %%
# Retrieving only the text and score columns while drop NAN values

reviews = reviews.loc[:, ['Text', 'Score']]
reviews = reviews.dropna(how='any')
reviews.head(1)
# Out:
#                                                 Text  Score
# 0  I have bought several of the Vitality canned d...      5

# %%
reviews.loc[reviews['Score'] <= 2, 'Score'] = 0 
reviews.loc[reviews['Score'] > 3, 'Score'] = 1
reviews.drop(reviews[reviews['Score']==3].index, inplace=True)
        
reviews.shape
# Out:
# (525814, 2)

# %% [markdown]
# # EDA

# %%
def get_wordlen(x):
    return len(x.split())
reviews['len'] = reviews.Text.apply(get_wordlen)
reviews = reviews[reviews.len<50]
reviews = reviews.sample(n=100000, random_state=30)

def remove_html(text):
    html_pattern = re.compile('<.*?>')
    return html_pattern.sub(r'', text)

text=reviews['Text']
preprocesstext=text.map(remove_html)
reviews['Text']=preprocesstext

#print head 5
reviews.head(5)
# Out:
#                                                      Text  Score  len
# 64117   The tea was of great quality and it tasted lik...      1   30
# 418112  My cat loves this.  The pellets are nice and s...      1   31
# 357829  Great product. Does not completely get rid of ...      1   41
# 175872  This gum is my favorite!  I would advise every...      1   27
# 178716  I also found out about this product because of...      1   22

# %%
# Split the data into train and test data(20%) with Stratify sampling and random state 33 

from sklearn.model_selection import train_test_split
X = reviews['Text']
y = reviews["Score"].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, stratify=y, random_state = 33)

# %%
# Saving to disk. if we need, we can load preprocessed data directly. 
reviews.to_csv('preprocessed.csv', index=False)

# %% [markdown]
# # Set up pretrained model & vocab file for training

# %%
## Loading the Pretrained Model from tensorflow HUB
tf.keras.backend.clear_session()

max_seq_length = 55

# Creating the necessary requirements
input_word_ids = tf.keras.layers.Input(shape=(max_seq_length,), dtype=tf.int32, name="input_word_ids")
input_mask = tf.keras.layers.Input(shape=(max_seq_length,), dtype=tf.int32, name="input_mask")
segment_ids = tf.keras.layers.Input(shape=(max_seq_length,), dtype=tf.int32, name="segment_ids")

#bert layer 
bert_layer = hub.KerasLayer("https://tfhub.dev/tensorflow/bert_en_uncased_L-12_H-768_A-12/1", trainable=False)
pooled_output, sequence_output = bert_layer([input_word_ids, input_mask, segment_ids])

bert_model = Model(inputs=[input_word_ids, input_mask, segment_ids], outputs=pooled_output)
bert_model.summary()
# Out:
# 2022-05-18 20:20:28.161294: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1052] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-18 20:20:28.210176: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1052] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-18 20:20:28.210750: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1052] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-18 20:20:28.213076: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1052] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-18 20:20:28.213561: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1052] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-18 20:20:28.214004: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1052] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-18 20:20:29.035548: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1052] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-18 20:20:29.035823: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1052] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-18 20:20:29.036065: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:1052] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-18 20:20:29.036256: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7251 MB memory:  -> device: 0, name: Quadro P4000, pci bus id: 0000:00:05.0, compute capability: 6.1
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_word_ids (InputLayer)    [(None, 55)]         0           []
#
#  input_mask (InputLayer)        [(None, 55)]         0           []
#
#  segment_ids (InputLayer)       [(None, 55)]         0           []
#
#  keras_layer (KerasLayer)       [(None, 768),        109482241   ['input_word_ids[0][0]',
#                                  (None, 55, 768)]                 'input_mask[0][0]',
#                                                                   'segment_ids[0][0]']
#
# ==================================================================================================
# Total params: 109,482,241
# Trainable params: 0
# Non-trainable params: 109,482,241
# __________________________________________________________________________________________________

# %%
#getting Vocab file
vocab_file = bert_layer.resolved_object.vocab_file.asset_path.numpy()
do_lower_case = bert_layer.resolved_object.do_lower_case.numpy()

#import tokenization from the GitHub link provided
import tokenization

tokenizer = tokenization.FullTokenizer(vocab_file, do_lower_case)

X_train=np.array(X_train)
# print(X_train[0])
X_train_tokens = []
X_train_mask = []
X_train_segment = []
X_test_tokens = []
X_test_mask = []
X_test_segment = []

def TokenizeAndConvertToIds(text):
    tokens= tokenizer.tokenize(reviews) # tokenize the reviews
    tokens=tokens[0:(max_seq_length-2)] 
    tokens=['[CLS]',*tokens,'[SEP]'] # adding cls and sep at the end
    masked_array=np.array([1]*len(tokens) + [0]* (max_seq_length-len(tokens))) # masking 
    segment_array=np.array([0]*max_seq_length)
    if(len(tokens)<max_seq_length):
        padding=['[PAD]']*(max_seq_length-len(tokens)) # padding
        tokens=[*tokens,*padding]
    tokentoid=np.array(tokenizer.convert_tokens_to_ids(tokens)) # converting the tokens to id
    return tokentoid,masked_array,segment_array

for reviews in tqdm(X_train):
    tokentoid,masked_array,segment_array=TokenizeAndConvertToIds(reviews)
    X_train_tokens.append(tokentoid)
    X_train_mask.append(masked_array)
    X_train_segment.append(segment_array)
    
for reviews in tqdm(X_test):
    tokentoid,masked_array,segment_array=TokenizeAndConvertToIds(reviews)
    X_test_tokens.append(tokentoid)
    X_test_mask.append(masked_array)
    X_test_segment.append(segment_array)
    
X_train_tokens = np.array(X_train_tokens)
X_train_mask = np.array(X_train_mask)
X_train_segment = np.array(X_train_segment)
X_test_tokens = np.array(X_test_tokens)
X_test_mask = np.array(X_test_mask)
X_test_segment = np.array(X_test_segment)
# Out:
# 100%|██████████| 80000/80000 [00:40<00:00, 1991.34it/s]
# 100%|██████████| 20000/20000 [00:09<00:00, 2043.83it/s]

# %%
import pickle

# save all your results to disk so that, no need to run all again. 
pickle.dump((X_train, X_train_tokens, X_train_mask, X_train_segment, y_train),open('train_data.pkl','wb'))
pickle.dump((X_test, X_test_tokens, X_test_mask, X_test_segment, y_test),open('test_data.pkl','wb'))

# you can load from disk
X_train, X_train_tokens, X_train_mask, X_train_segment, y_train = pickle.load(open("train_data.pkl", 'rb')) 
X_test, X_test_tokens, X_test_mask, X_test_segment, y_test = pickle.load(open("test_data.pkl", 'rb'))

# %%
# get the train output with the BERT model
X_train_pooled_output=bert_model.predict([X_train_tokens,X_train_mask,X_train_segment])

# get the test output with the BERT model
X_test_pooled_output=bert_model.predict([X_test_tokens,X_test_mask,X_test_segment])

# %%
# save all the results to the respective folder to avoid running the previous predictions again. 
pickle.dump((X_train_pooled_output, X_test_pooled_output),open('final_output.pkl','wb'))

# load the data for second utility
X_train_pooled_output, X_test_pooled_output= pickle.load(open('final_output.pkl', 'rb'))

# %% [markdown]
# # Add transfer learning layers and initialize models

# %%
# input layer
input_layer=Input(shape=(768,), name='input_layer') 

# Dense layer
layer1 = Dense(50,activation='relu',kernel_initializer=tf.keras.initializers.RandomUniform(0,1), name='layer1')(input_layer) 

# MaxPool Layer
Normal1 = BatchNormalization()(layer1)

# Flatten
flatten = Flatten(data_format='channels_last',name='Flatten')(Normal1)

# FC layer
FC1 = Dense(units=30,activation='relu',kernel_initializer=tf.keras.initializers.glorot_normal(seed=32),name='FC1')(flatten)

# FC layer
FC2 = Dense(units=30,activation='relu',kernel_initializer=tf.keras.initializers.glorot_normal(seed=33),name='FC2')(FC1)

# output layer
Out = Dense(units=1,activation= "sigmoid", kernel_initializer=tf.keras.initializers.glorot_normal(seed=3),name='Output')(FC2)

model = Model(inputs=input_layer,outputs=Out)

# %%
checkpoint = ModelCheckpoint("best_model1.hdf5", monitor='accuracy', verbose=1,
    save_best_only=True, mode='auto', save_freq=1)

reduce = ReduceLROnPlateau(monitor='accuracy', factor=0.2, patience=2, min_lr=0.0001, verbose = 1)

def auroc(y_true, y_pred):
    return tf.py_function(roc_auc_score, (y_true, y_pred), tf.double)

logdir = os.path.join("logs", datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_Visualization = TensorBoard(log_dir=logdir, histogram_freq=1)

# %% [markdown]
# # Fit the model

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', auroc])

model.fit(X_train_pooled_output, y_train, 
          validation_split=0.2, 
          epochs=10, 
          batch_size = 300,
          callbacks=[checkpoint, reduce, tensorboard_Visualization])
# Out:
# Epoch 1/10
#
# Epoch 00001: accuracy improved from -inf to 0.52667, saving model to best_model1.hdf5
#   1/214 [..............................] - ETA: 3:56 - loss: 0.6938 - accuracy: 0.5267 - auroc: 0.4553
# Epoch 00001: accuracy improved from 0.52667 to 0.56833, saving model to best_model1.hdf5
#   2/214 [..............................] - ETA: 2:37 - loss: 0.6755 - accuracy: 0.5683 - auroc: 0.4533
# Epoch 00001: accuracy improved from 0.56833 to 0.62000, saving model to best_model1.hdf5
#   3/214 [..............................] - ETA: 2:40 - loss: 0.6688 - accuracy: 0.6200 - auroc: 0.4475
# Epoch 00001: accuracy improved from 0.62000 to 0.66000, saving model to best_model1.hdf5
#   4/214 [..............................] - ETA: 2:27 - loss: 0.6518 - accuracy: 0.6600 - auroc: 0.4648
# Epoch 00001: accuracy improved from 0.66000 to 0.68800, saving model to best_model1.hdf5
#   5/214 [..............................] - ETA: 2:26 - loss: 0.6418 - accuracy: 0.6880 - auroc: 0.4591
# Epoch 00001: accuracy improved from 0.68800 to 0.72167, saving model to best_model1.hdf5
#   6/214 [..............................] - ETA: 2:25 - loss: 0.6272 - accuracy: 0.7217 - auroc: 0.4689
# Epoch 00001: accuracy improved from 0.72167 to 0.73857, saving model to best_model1.hdf5
#   7/214 [..............................] - ETA: 2:30 - loss: 0.6174 - accuracy: 0.7386 - auroc: 0.4783
# Epoch 00001: accuracy improved from 0.73857 to 0.75708, saving model to best_model1.hdf5
#   8/214 [>.............................] - ETA: 2:35 - loss: 0.6075 - accuracy: 0.7571 - auroc: 0.4731
# Epoch 00001: accuracy improved from 0.75708 to 0.77148, saving model to best_model1.hdf5
#   9/214 [>.............................] - ETA: 2:33 - loss: 0.5973 - accuracy: 0.7715 - auroc: 0.4752
# Epoch 00001: accuracy improved from 0.77148 to 0.78000, saving model to best_model1.hdf5
#  10/214 [>.............................] - ETA: 2:27 - loss: 0.5885 - accuracy: 0.7800 - auroc: 0.4756
# Epoch 00001: accuracy improved from 0.78000 to 0.79182, saving model to best_model1.hdf5
#  11/214 [>.............................] - ETA: 2:27 - loss: 0.5764 - accuracy: 0.7918 - auroc: 0.4829
# Epoch 00001: accuracy improved from 0.79182 to 0.80028, saving model to best_model1.hdf5
#  12/214 [>.............................] - ETA: 2:25 - loss: 0.5674 - accuracy: 0.8003 - auroc: 0.4873
# Epoch 00001: accuracy improved from 0.80028 to 0.80487, saving model to best_model1.hdf5
#  13/214 [>.............................] - ETA: 2:22 - loss: 0.5608 - accuracy: 0.8049 - auroc: 0.4883
# Epoch 00001: accuracy improved from 0.80487 to 0.81071, saving model to best_model1.hdf5
#  14/214 [>.............................] - ETA: 2:19 - loss: 0.5534 - accuracy: 0.8107 - auroc: 0.4882
# Epoch 00001: accuracy improved from 0.81071 to 0.81422, saving model to best_model1.hdf5
#  15/214 [=>............................] - ETA: 2:18 - loss: 0.5464 - accuracy: 0.8142 - auroc: 0.4945
# Epoch 00001: accuracy improved from 0.81422 to 0.81687, saving model to best_model1.hdf5
#  16/214 [=>............................] - ETA: 2:16 - loss: 0.5425 - accuracy: 0.8169 - auroc: 0.4921
# Epoch 00001: accuracy improved from 0.81687 to 0.82020, saving model to best_model1.hdf5
#  17/214 [=>............................] - ETA: 2:13 - loss: 0.5372 - accuracy: 0.8202 - auroc: 0.4899
# Epoch 00001: accuracy improved from 0.82020 to 0.82111, saving model to best_model1.hdf5
#  18/214 [=>............................] - ETA: 2:10 - loss: 0.5344 - accuracy: 0.8211 - auroc: 0.4891
# Epoch 00001: accuracy improved from 0.82111 to 0.82386, saving model to best_model1.hdf5
#  19/214 [=>............................] - ETA: 2:09 - loss: 0.5294 - accuracy: 0.8239 - auroc: 0.4859
# Epoch 00001: accuracy improved from 0.82386 to 0.82567, saving model to best_model1.hdf5
#  20/214 [=>............................] - ETA: 2:07 - loss: 0.5242 - accuracy: 0.8257 - auroc: 0.4879
# Epoch 00001: accuracy improved from 0.82567 to 0.82587, saving model to best_model1.hdf5
#  21/214 [=>............................] - ETA: 2:04 - loss: 0.5233 - accuracy: 0.8259 - auroc: 0.4857
# Epoch 00001: accuracy improved from 0.82587 to 0.82606, saving model to best_model1.hdf5
#  22/214 [==>...........................] - ETA: 2:02 - loss: 0.5205 - accuracy: 0.8261 - auroc: 0.4892
# Epoch 00001: accuracy improved from 0.82606 to 0.82826, saving model to best_model1.hdf5
#  23/214 [==>...........................] - ETA: 2:03 - loss: 0.5153 - accuracy: 0.8283 - auroc: 0.4881
# Epoch 00001: accuracy improved from 0.82826 to 0.83000, saving model to best_model1.hdf5
#  24/214 [==>...........................] - ETA: 2:03 - loss: 0.5107 - accuracy: 0.8300 - auroc: 0.4891
# Epoch 00001: accuracy improved from 0.83000 to 0.83320, saving model to best_model1.hdf5
#  25/214 [==>...........................] - ETA: 2:03 - loss: 0.5040 - accuracy: 0.8332 - auroc: 0.4915
# Epoch 00001: accuracy improved from 0.83320 to 0.83436, saving model to best_model1.hdf5
#  26/214 [==>...........................] - ETA: 2:03 - loss: 0.5007 - accuracy: 0.8344 - auroc: 0.4926
# Epoch 00001: accuracy improved from 0.83436 to 0.83519, saving model to best_model1.hdf5
#  27/214 [==>...........................] - ETA: 2:02 - loss: 0.4982 - accuracy: 0.8352 - auroc: 0.4930
# Epoch 00001: accuracy improved from 0.83519 to 0.83679, saving model to best_model1.hdf5
#  28/214 [==>...........................] - ETA: 2:01 - loss: 0.4946 - accuracy: 0.8368 - auroc: 0.4940
# Epoch 00001: accuracy improved from 0.83679 to 0.83724, saving model to best_model1.hdf5
#  29/214 [===>..........................] - ETA: 2:01 - loss: 0.4921 - accuracy: 0.8372 - auroc: 0.4970
# Epoch 00001: accuracy improved from 0.83724 to 0.83867, saving model to best_model1.hdf5
#  30/214 [===>..........................] - ETA: 2:01 - loss: 0.4886 - accuracy: 0.8387 - auroc: 0.4979
# Epoch 00001: accuracy improved from 0.83867 to 0.83935, saving model to best_model1.hdf5
#  31/214 [===>..........................] - ETA: 2:00 - loss: 0.4863 - accuracy: 0.8394 - auroc: 0.4998
# Epoch 00001: accuracy improved from 0.83935 to 0.84115, saving model to best_model1.hdf5
#  32/214 [===>..........................] - ETA: 2:01 - loss: 0.4821 - accuracy: 0.8411 - auroc: 0.5024
# Epoch 00001: accuracy improved from 0.84115 to 0.84172, saving model to best_model1.hdf5
#  33/214 [===>..........................] - ETA: 2:00 - loss: 0.4792 - accuracy: 0.8417 - auroc: 0.5077
# Epoch 00001: accuracy improved from 0.84172 to 0.84294, saving model to best_model1.hdf5
#  34/214 [===>..........................] - ETA: 1:59 - loss: 0.4757 - accuracy: 0.8429 - auroc: 0.5104
# Epoch 00001: accuracy improved from 0.84294 to 0.84381, saving model to best_model1.hdf5
#  35/214 [===>..........................] - ETA: 1:58 - loss: 0.4727 - accuracy: 0.8438 - auroc: 0.5133
# Epoch 00001: accuracy improved from 0.84381 to 0.84426, saving model to best_model1.hdf5
#  36/214 [====>.........................] - ETA: 1:56 - loss: 0.4706 - accuracy: 0.8443 - auroc: 0.5159
# Epoch 00001: accuracy did not improve from 0.84426
#
# Epoch 00001: accuracy did not improve from 0.84426
#
# Epoch 00001: accuracy improved from 0.84426 to 0.84470, saving model to best_model1.hdf5
#  39/214 [====>.........................] - ETA: 1:48 - loss: 0.4670 - accuracy: 0.8447 - auroc: 0.5202
# Epoch 00001: accuracy improved from 0.84470 to 0.84508, saving model to best_model1.hdf5
#  40/214 [====>.........................] - ETA: 1:48 - loss: 0.4649 - accuracy: 0.8451 - auroc: 0.5236
# Epoch 00001: accuracy improved from 0.84508 to 0.84642, saving model to best_model1.hdf5
#  41/214 [====>.........................] - ETA: 1:47 - loss: 0.4616 - accuracy: 0.8464 - auroc: 0.5264
# Epoch 00001: accuracy improved from 0.84642 to 0.84746, saving model to best_model1.hdf5
#  42/214 [====>.........................] - ETA: 1:47 - loss: 0.4587 - accuracy: 0.8475 - auroc: 0.5300
# Epoch 00001: accuracy improved from 0.84746 to 0.84767, saving model to best_model1.hdf5
#  43/214 [=====>........................] - ETA: 1:46 - loss: 0.4571 - accuracy: 0.8477 - auroc: 0.5329
# Epoch 00001: accuracy improved from 0.84767 to 0.84803, saving model to best_model1.hdf5
#  44/214 [=====>........................] - ETA: 1:46 - loss: 0.4555 - accuracy: 0.8480 - auroc: 0.5347
# Epoch 00001: accuracy improved from 0.84803 to 0.84874, saving model to best_model1.hdf5
#  45/214 [=====>........................] - ETA: 1:45 - loss: 0.4533 - accuracy: 0.8487 - auroc: 0.5373
# Epoch 00001: accuracy improved from 0.84874 to 0.84928, saving model to best_model1.hdf5
#  46/214 [=====>........................] - ETA: 1:45 - loss: 0.4514 - accuracy: 0.8493 - auroc: 0.5402
# Epoch 00001: accuracy did not improve from 0.84928
#
# Epoch 00001: accuracy improved from 0.84928 to 0.85028, saving model to best_model1.hdf5
#  48/214 [=====>........................] - ETA: 1:42 - loss: 0.4481 - accuracy: 0.8503 - auroc: 0.5448
# Epoch 00001: accuracy improved from 0.85028 to 0.85034, saving model to best_model1.hdf5
#  49/214 [=====>........................] - ETA: 1:41 - loss: 0.4467 - accuracy: 0.8503 - auroc: 0.5496
# Epoch 00001: accuracy improved from 0.85034 to 0.85053, saving model to best_model1.hdf5
#  50/214 [======>.......................] - ETA: 1:41 - loss: 0.4456 - accuracy: 0.8505 - auroc: 0.5516
# Epoch 00001: accuracy improved from 0.85053 to 0.85150, saving model to best_model1.hdf5
#  51/214 [======>.......................] - ETA: 1:41 - loss: 0.4430 - accuracy: 0.8515 - auroc: 0.5541
# Epoch 00001: accuracy improved from 0.85150 to 0.85167, saving model to best_model1.hdf5
#  52/214 [======>.......................] - ETA: 1:40 - loss: 0.4416 - accuracy: 0.8517 - auroc: 0.5583
# Epoch 00001: accuracy improved from 0.85167 to 0.85220, saving model to best_model1.hdf5
#  53/214 [======>.......................] - ETA: 1:39 - loss: 0.4398 - accuracy: 0.8522 - auroc: 0.5612
# Epoch 00001: accuracy improved from 0.85220 to 0.85259, saving model to best_model1.hdf5
#  54/214 [======>.......................] - ETA: 1:38 - loss: 0.4381 - accuracy: 0.8526 - auroc: 0.5640
# Epoch 00001: accuracy improved from 0.85259 to 0.85297, saving model to best_model1.hdf5
#  55/214 [======>.......................] - ETA: 1:37 - loss: 0.4365 - accuracy: 0.8530 - auroc: 0.5669
# Epoch 00001: accuracy improved from 0.85297 to 0.85345, saving model to best_model1.hdf5
#  56/214 [======>.......................] - ETA: 1:37 - loss: 0.4348 - accuracy: 0.8535 - auroc: 0.5702
# Epoch 00001: accuracy improved from 0.85345 to 0.85363, saving model to best_model1.hdf5
#  57/214 [======>.......................] - ETA: 1:36 - loss: 0.4338 - accuracy: 0.8536 - auroc: 0.5725
# Epoch 00001: accuracy improved from 0.85363 to 0.85420, saving model to best_model1.hdf5
#  58/214 [=======>......................] - ETA: 1:36 - loss: 0.4316 - accuracy: 0.8542 - auroc: 0.5767
# Epoch 00001: accuracy improved from 0.85420 to 0.85480, saving model to best_model1.hdf5
#  59/214 [=======>......................] - ETA: 1:36 - loss: 0.4295 - accuracy: 0.8548 - auroc: 0.5805
# Epoch 00001: accuracy improved from 0.85480 to 0.85494, saving model to best_model1.hdf5
#  60/214 [=======>......................] - ETA: 1:35 - loss: 0.4283 - accuracy: 0.8549 - auroc: 0.5842
# Epoch 00001: accuracy improved from 0.85494 to 0.85519, saving model to best_model1.hdf5
#  61/214 [=======>......................] - ETA: 1:34 - loss: 0.4269 - accuracy: 0.8552 - auroc: 0.5874
# Epoch 00001: accuracy improved from 0.85519 to 0.85559, saving model to best_model1.hdf5
#  62/214 [=======>......................] - ETA: 1:34 - loss: 0.4253 - accuracy: 0.8556 - auroc: 0.5902
# Epoch 00001: accuracy did not improve from 0.85559
#
# Epoch 00001: accuracy did not improve from 0.85559
#
# Epoch 00001: accuracy did not improve from 0.85559
#
# Epoch 00001: accuracy did not improve from 0.85559
#
# Epoch 00001: accuracy improved from 0.85559 to 0.85607, saving model to best_model1.hdf5
#  67/214 [========>.....................] - ETA: 1:25 - loss: 0.4205 - accuracy: 0.8561 - auroc: 0.6029
# Epoch 00001: accuracy did not improve from 0.85607
#
# Epoch 00001: accuracy improved from 0.85607 to 0.85609, saving model to best_model1.hdf5
#  69/214 [========>.....................] - ETA: 1:24 - loss: 0.4188 - accuracy: 0.8561 - auroc: 0.6081
# Epoch 00001: accuracy improved from 0.85609 to 0.85610, saving model to best_model1.hdf5
#  70/214 [========>.....................] - ETA: 1:24 - loss: 0.4178 - accuracy: 0.8561 - auroc: 0.6111
# Epoch 00001: accuracy improved from 0.85610 to 0.85648, saving model to best_model1.hdf5
#  71/214 [========>.....................] - ETA: 1:24 - loss: 0.4163 - accuracy: 0.8565 - auroc: 0.6141
# Epoch 00001: accuracy improved from 0.85648 to 0.85745, saving model to best_model1.hdf5
#  72/214 [=========>....................] - ETA: 1:24 - loss: 0.4140 - accuracy: 0.8575 - auroc: 0.6166
# Epoch 00001: accuracy improved from 0.85745 to 0.85767, saving model to best_model1.hdf5
#  73/214 [=========>....................] - ETA: 1:23 - loss: 0.4129 - accuracy: 0.8577 - auroc: 0.6190
# Epoch 00001: accuracy did not improve from 0.85767
#
# Epoch 00001: accuracy did not improve from 0.85767
#
# Epoch 00001: accuracy improved from 0.85767 to 0.85781, saving model to best_model1.hdf5
#  76/214 [=========>....................] - ETA: 1:19 - loss: 0.4098 - accuracy: 0.8578 - auroc: 0.6273
# Epoch 00001: accuracy did not improve from 0.85781
#
# Epoch 00001: accuracy improved from 0.85781 to 0.85799, saving model to best_model1.hdf5
#  78/214 [=========>....................] - ETA: 1:17 - loss: 0.4076 - accuracy: 0.8580 - auroc: 0.6328
# Epoch 00001: accuracy did not improve from 0.85799
#
# Epoch 00001: accuracy did not improve from 0.85799
#
# Epoch 00001: accuracy improved from 0.85799 to 0.85802, saving model to best_model1.hdf5
#  81/214 [==========>...................] - ETA: 1:14 - loss: 0.4052 - accuracy: 0.8580 - auroc: 0.6388
# Epoch 00001: accuracy improved from 0.85802 to 0.85805, saving model to best_model1.hdf5
#  82/214 [==========>...................] - ETA: 1:13 - loss: 0.4042 - accuracy: 0.8580 - auroc: 0.6411
# Epoch 00001: accuracy did not improve from 0.85805
#
# Epoch 00001: accuracy did not improve from 0.85805
#
# Epoch 00001: accuracy did not improve from 0.85805
#
# Epoch 00001: accuracy did not improve from 0.85805
#
# Epoch 00001: accuracy did not improve from 0.85805
#
# Epoch 00001: accuracy improved from 0.85805 to 0.85811, saving model to best_model1.hdf5
#  88/214 [===========>..................] - ETA: 1:06 - loss: 0.3996 - accuracy: 0.8581 - auroc: 0.6528
# Epoch 00001: accuracy improved from 0.85811 to 0.85820, saving model to best_model1.hdf5
#  89/214 [===========>..................] - ETA: 1:06 - loss: 0.3985 - accuracy: 0.8582 - auroc: 0.6548
# Epoch 00001: accuracy improved from 0.85820 to 0.85822, saving model to best_model1.hdf5
#  90/214 [===========>..................] - ETA: 1:06 - loss: 0.3975 - accuracy: 0.8582 - auroc: 0.6572
# Epoch 00001: accuracy improved from 0.85822 to 0.85824, saving model to best_model1.hdf5
#  91/214 [===========>..................] - ETA: 1:05 - loss: 0.3966 - accuracy: 0.8582 - auroc: 0.6594
# Epoch 00001: accuracy improved from 0.85824 to 0.85870, saving model to best_model1.hdf5
#  92/214 [===========>..................] - ETA: 1:05 - loss: 0.3951 - accuracy: 0.8587 - auroc: 0.6615
# Epoch 00001: accuracy did not improve from 0.85870
#
# Epoch 00001: accuracy improved from 0.85870 to 0.85872, saving model to best_model1.hdf5
#  94/214 [============>.................] - ETA: 1:04 - loss: 0.3936 - accuracy: 0.8587 - auroc: 0.6652
# Epoch 00001: accuracy improved from 0.85872 to 0.85923, saving model to best_model1.hdf5
#  95/214 [============>.................] - ETA: 1:03 - loss: 0.3923 - accuracy: 0.8592 - auroc: 0.6663
# Epoch 00001: accuracy did not improve from 0.85923
#
# Epoch 00001: accuracy improved from 0.85923 to 0.85948, saving model to best_model1.hdf5
#  97/214 [============>.................] - ETA: 1:02 - loss: 0.3904 - accuracy: 0.8595 - auroc: 0.6704
# Epoch 00001: accuracy improved from 0.85948 to 0.85976, saving model to best_model1.hdf5
#  98/214 [============>.................] - ETA: 1:01 - loss: 0.3891 - accuracy: 0.8598 - auroc: 0.6724
# Epoch 00001: accuracy did not improve from 0.85976
#
# Epoch 00001: accuracy did not improve from 0.85976
#
# Epoch 00001: accuracy improved from 0.85976 to 0.86007, saving model to best_model1.hdf5
# 101/214 [=============>................] - ETA: 59s - loss: 0.3859 - accuracy: 0.8601 - auroc: 0.6790
# Epoch 00001: accuracy did not improve from 0.86007
#
# Epoch 00001: accuracy improved from 0.86007 to 0.86039, saving model to best_model1.hdf5
# 103/214 [=============>................] - ETA: 57s - loss: 0.3836 - accuracy: 0.8604 - auroc: 0.6830
# Epoch 00001: accuracy improved from 0.86039 to 0.86058, saving model to best_model1.hdf5
# 104/214 [=============>................] - ETA: 57s - loss: 0.3825 - accuracy: 0.8606 - auroc: 0.6847
# Epoch 00001: accuracy improved from 0.86058 to 0.86083, saving model to best_model1.hdf5
# 105/214 [=============>................] - ETA: 56s - loss: 0.3816 - accuracy: 0.8608 - auroc: 0.6863
# Epoch 00001: accuracy did not improve from 0.86083
#
# Epoch 00001: accuracy did not improve from 0.86083
#
# Epoch 00001: accuracy improved from 0.86083 to 0.86102, saving model to best_model1.hdf5
# 108/214 [==============>...............] - ETA: 54s - loss: 0.3791 - accuracy: 0.8610 - auroc: 0.6911
# Epoch 00001: accuracy improved from 0.86102 to 0.86113, saving model to best_model1.hdf5
# 109/214 [==============>...............] - ETA: 54s - loss: 0.3781 - accuracy: 0.8611 - auroc: 0.6929
# Epoch 00001: accuracy improved from 0.86113 to 0.86142, saving model to best_model1.hdf5
# 110/214 [==============>...............] - ETA: 53s - loss: 0.3768 - accuracy: 0.8614 - auroc: 0.6950
# Epoch 00001: accuracy did not improve from 0.86142
#
# Epoch 00001: accuracy did not improve from 0.86142
#
# Epoch 00001: accuracy did not improve from 0.86142
#
# Epoch 00001: accuracy did not improve from 0.86142
#
# Epoch 00001: accuracy did not improve from 0.86142
#
# Epoch 00001: accuracy improved from 0.86142 to 0.86158, saving model to best_model1.hdf5
# 116/214 [===============>..............] - ETA: 48s - loss: 0.3722 - accuracy: 0.8616 - auroc: 0.7051
# Epoch 00001: accuracy improved from 0.86158 to 0.86179, saving model to best_model1.hdf5
# 117/214 [===============>..............] - ETA: 48s - loss: 0.3714 - accuracy: 0.8618 - auroc: 0.7064
# Epoch 00001: accuracy improved from 0.86179 to 0.86209, saving model to best_model1.hdf5
# 118/214 [===============>..............] - ETA: 47s - loss: 0.3703 - accuracy: 0.8621 - auroc: 0.7079
# Epoch 00001: accuracy improved from 0.86209 to 0.86216, saving model to best_model1.hdf5
# 119/214 [===============>..............] - ETA: 47s - loss: 0.3696 - accuracy: 0.8622 - auroc: 0.7093
# Epoch 00001: accuracy improved from 0.86216 to 0.86236, saving model to best_model1.hdf5
# 120/214 [===============>..............] - ETA: 47s - loss: 0.3688 - accuracy: 0.8624 - auroc: 0.7109
# Epoch 00001: accuracy improved from 0.86236 to 0.86245, saving model to best_model1.hdf5
# 121/214 [===============>..............] - ETA: 46s - loss: 0.3680 - accuracy: 0.8625 - auroc: 0.7125
# Epoch 00001: accuracy improved from 0.86245 to 0.86276, saving model to best_model1.hdf5
# 122/214 [================>.............] - ETA: 46s - loss: 0.3670 - accuracy: 0.8628 - auroc: 0.7141
# Epoch 00001: accuracy improved from 0.86276 to 0.86331, saving model to best_model1.hdf5
# 123/214 [================>.............] - ETA: 46s - loss: 0.3658 - accuracy: 0.8633 - auroc: 0.7157
# Epoch 00001: accuracy improved from 0.86331 to 0.86341, saving model to best_model1.hdf5
# 124/214 [================>.............] - ETA: 45s - loss: 0.3650 - accuracy: 0.8634 - auroc: 0.7173
# Epoch 00001: accuracy improved from 0.86341 to 0.86365, saving model to best_model1.hdf5
# 125/214 [================>.............] - ETA: 45s - loss: 0.3641 - accuracy: 0.8637 - auroc: 0.7187
# Epoch 00001: accuracy did not improve from 0.86365
#
# Epoch 00001: accuracy improved from 0.86365 to 0.86383, saving model to best_model1.hdf5
# 127/214 [================>.............] - ETA: 43s - loss: 0.3625 - accuracy: 0.8638 - auroc: 0.7216
# Epoch 00001: accuracy improved from 0.86383 to 0.86401, saving model to best_model1.hdf5
# 128/214 [================>.............] - ETA: 43s - loss: 0.3616 - accuracy: 0.8640 - auroc: 0.7228
# Epoch 00001: accuracy improved from 0.86401 to 0.86424, saving model to best_model1.hdf5
# 129/214 [=================>............] - ETA: 43s - loss: 0.3607 - accuracy: 0.8642 - auroc: 0.7241
# Epoch 00001: accuracy improved from 0.86424 to 0.86446, saving model to best_model1.hdf5
# 130/214 [=================>............] - ETA: 42s - loss: 0.3599 - accuracy: 0.8645 - auroc: 0.7254
# Epoch 00001: accuracy improved from 0.86446 to 0.86468, saving model to best_model1.hdf5
# 131/214 [=================>............] - ETA: 42s - loss: 0.3591 - accuracy: 0.8647 - auroc: 0.7264
# Epoch 00001: accuracy improved from 0.86468 to 0.86495, saving model to best_model1.hdf5
# 132/214 [=================>............] - ETA: 41s - loss: 0.3580 - accuracy: 0.8649 - auroc: 0.7279
# Epoch 00001: accuracy improved from 0.86495 to 0.86529, saving model to best_model1.hdf5
# 133/214 [=================>............] - ETA: 41s - loss: 0.3569 - accuracy: 0.8653 - auroc: 0.7293
# Epoch 00001: accuracy improved from 0.86529 to 0.86570, saving model to best_model1.hdf5
# 134/214 [=================>............] - ETA: 41s - loss: 0.3559 - accuracy: 0.8657 - auroc: 0.7306
# Epoch 00001: accuracy did not improve from 0.86570
#
# Epoch 00001: accuracy improved from 0.86570 to 0.86586, saving model to best_model1.hdf5
# 136/214 [==================>...........] - ETA: 39s - loss: 0.3542 - accuracy: 0.8659 - auroc: 0.7333
# Epoch 00001: accuracy improved from 0.86586 to 0.86606, saving model to best_model1.hdf5
# 137/214 [==================>...........] - ETA: 39s - loss: 0.3535 - accuracy: 0.8661 - auroc: 0.7344
# Epoch 00001: accuracy improved from 0.86606 to 0.86630, saving model to best_model1.hdf5
# 138/214 [==================>...........] - ETA: 38s - loss: 0.3528 - accuracy: 0.8663 - auroc: 0.7357
# Epoch 00001: accuracy improved from 0.86630 to 0.86667, saving model to best_model1.hdf5
# 139/214 [==================>...........] - ETA: 38s - loss: 0.3517 - accuracy: 0.8667 - auroc: 0.7370
# Epoch 00001: accuracy improved from 0.86667 to 0.86695, saving model to best_model1.hdf5
# 140/214 [==================>...........] - ETA: 37s - loss: 0.3507 - accuracy: 0.8670 - auroc: 0.7383
# Epoch 00001: accuracy improved from 0.86695 to 0.86716, saving model to best_model1.hdf5
# 141/214 [==================>...........] - ETA: 37s - loss: 0.3501 - accuracy: 0.8672 - auroc: 0.7394
# Epoch 00001: accuracy improved from 0.86716 to 0.86754, saving model to best_model1.hdf5
# 142/214 [==================>...........] - ETA: 36s - loss: 0.3490 - accuracy: 0.8675 - auroc: 0.7405
# Epoch 00001: accuracy improved from 0.86754 to 0.86802, saving model to best_model1.hdf5
# 143/214 [===================>..........] - ETA: 36s - loss: 0.3479 - accuracy: 0.8680 - auroc: 0.7418
# Epoch 00001: accuracy improved from 0.86802 to 0.86815, saving model to best_model1.hdf5
# 144/214 [===================>..........] - ETA: 35s - loss: 0.3473 - accuracy: 0.8681 - auroc: 0.7427
# Epoch 00001: accuracy improved from 0.86815 to 0.86828, saving model to best_model1.hdf5
# 145/214 [===================>..........] - ETA: 35s - loss: 0.3468 - accuracy: 0.8683 - auroc: 0.7437
# Epoch 00001: accuracy improved from 0.86828 to 0.86840, saving model to best_model1.hdf5
# 146/214 [===================>..........] - ETA: 34s - loss: 0.3463 - accuracy: 0.8684 - auroc: 0.7448
# Epoch 00001: accuracy improved from 0.86840 to 0.86857, saving model to best_model1.hdf5
# 147/214 [===================>..........] - ETA: 34s - loss: 0.3456 - accuracy: 0.8686 - auroc: 0.7458
# Epoch 00001: accuracy improved from 0.86857 to 0.86865, saving model to best_model1.hdf5
# 148/214 [===================>..........] - ETA: 34s - loss: 0.3450 - accuracy: 0.8686 - auroc: 0.7468
# Epoch 00001: accuracy improved from 0.86865 to 0.86872, saving model to best_model1.hdf5
# 149/214 [===================>..........] - ETA: 33s - loss: 0.3447 - accuracy: 0.8687 - auroc: 0.7476
# Epoch 00001: accuracy improved from 0.86872 to 0.86902, saving model to best_model1.hdf5
# 150/214 [====================>.........] - ETA: 33s - loss: 0.3439 - accuracy: 0.8690 - auroc: 0.7487
# Epoch 00001: accuracy improved from 0.86902 to 0.86921, saving model to best_model1.hdf5
# 151/214 [====================>.........] - ETA: 32s - loss: 0.3432 - accuracy: 0.8692 - auroc: 0.7496
# Epoch 00001: accuracy improved from 0.86921 to 0.86934, saving model to best_model1.hdf5
# 152/214 [====================>.........] - ETA: 32s - loss: 0.3426 - accuracy: 0.8693 - auroc: 0.7505
# Epoch 00001: accuracy improved from 0.86934 to 0.86952, saving model to best_model1.hdf5
# 153/214 [====================>.........] - ETA: 31s - loss: 0.3418 - accuracy: 0.8695 - auroc: 0.7515
# Epoch 00001: accuracy improved from 0.86952 to 0.86968, saving model to best_model1.hdf5
# 154/214 [====================>.........] - ETA: 31s - loss: 0.3413 - accuracy: 0.8697 - auroc: 0.7523
# Epoch 00001: accuracy improved from 0.86968 to 0.86983, saving model to best_model1.hdf5
# 155/214 [====================>.........] - ETA: 30s - loss: 0.3407 - accuracy: 0.8698 - auroc: 0.7532
# Epoch 00001: accuracy improved from 0.86983 to 0.86989, saving model to best_model1.hdf5
# 156/214 [====================>.........] - ETA: 30s - loss: 0.3401 - accuracy: 0.8699 - auroc: 0.7541
# Epoch 00001: accuracy improved from 0.86989 to 0.87008, saving model to best_model1.hdf5
# 157/214 [=====================>........] - ETA: 30s - loss: 0.3395 - accuracy: 0.8701 - auroc: 0.7552
# Epoch 00001: accuracy improved from 0.87008 to 0.87032, saving model to best_model1.hdf5
# 158/214 [=====================>........] - ETA: 29s - loss: 0.3388 - accuracy: 0.8703 - auroc: 0.7563
# Epoch 00001: accuracy improved from 0.87032 to 0.87063, saving model to best_model1.hdf5
# 159/214 [=====================>........] - ETA: 29s - loss: 0.3379 - accuracy: 0.8706 - auroc: 0.7574
# Epoch 00001: accuracy improved from 0.87063 to 0.87096, saving model to best_model1.hdf5
# 160/214 [=====================>........] - ETA: 28s - loss: 0.3370 - accuracy: 0.8710 - auroc: 0.7586
# Epoch 00001: accuracy improved from 0.87096 to 0.87128, saving model to best_model1.hdf5
# 161/214 [=====================>........] - ETA: 28s - loss: 0.3361 - accuracy: 0.8713 - auroc: 0.7597
# Epoch 00001: accuracy improved from 0.87128 to 0.87154, saving model to best_model1.hdf5
# 162/214 [=====================>........] - ETA: 27s - loss: 0.3354 - accuracy: 0.8715 - auroc: 0.7609
# Epoch 00001: accuracy improved from 0.87154 to 0.87188, saving model to best_model1.hdf5
# 163/214 [=====================>........] - ETA: 27s - loss: 0.3346 - accuracy: 0.8719 - auroc: 0.7618
# Epoch 00001: accuracy improved from 0.87188 to 0.87195, saving model to best_model1.hdf5
# 164/214 [=====================>........] - ETA: 26s - loss: 0.3340 - accuracy: 0.8720 - auroc: 0.7628
# Epoch 00001: accuracy improved from 0.87195 to 0.87220, saving model to best_model1.hdf5
# 165/214 [======================>.......] - ETA: 26s - loss: 0.3332 - accuracy: 0.8722 - auroc: 0.7638
# Epoch 00001: accuracy improved from 0.87220 to 0.87239, saving model to best_model1.hdf5
# 166/214 [======================>.......] - ETA: 25s - loss: 0.3327 - accuracy: 0.8724 - auroc: 0.7648
# Epoch 00001: accuracy improved from 0.87239 to 0.87255, saving model to best_model1.hdf5
# 167/214 [======================>.......] - ETA: 25s - loss: 0.3320 - accuracy: 0.8726 - auroc: 0.7659
# Epoch 00001: accuracy improved from 0.87255 to 0.87284, saving model to best_model1.hdf5
# 168/214 [======================>.......] - ETA: 24s - loss: 0.3312 - accuracy: 0.8728 - auroc: 0.7669
# Epoch 00001: accuracy improved from 0.87284 to 0.87296, saving model to best_model1.hdf5
# 169/214 [======================>.......] - ETA: 24s - loss: 0.3309 - accuracy: 0.8730 - auroc: 0.7675
# Epoch 00001: accuracy improved from 0.87296 to 0.87312, saving model to best_model1.hdf5
# 170/214 [======================>.......] - ETA: 23s - loss: 0.3303 - accuracy: 0.8731 - auroc: 0.7684
# Epoch 00001: accuracy improved from 0.87312 to 0.87329, saving model to best_model1.hdf5
# 171/214 [======================>.......] - ETA: 23s - loss: 0.3298 - accuracy: 0.8733 - auroc: 0.7693
# Epoch 00001: accuracy improved from 0.87329 to 0.87337, saving model to best_model1.hdf5
# 172/214 [=======================>......] - ETA: 22s - loss: 0.3293 - accuracy: 0.8734 - auroc: 0.7702
# Epoch 00001: accuracy improved from 0.87337 to 0.87376, saving model to best_model1.hdf5
# 173/214 [=======================>......] - ETA: 22s - loss: 0.3283 - accuracy: 0.8738 - auroc: 0.7712
# Epoch 00001: accuracy improved from 0.87376 to 0.87410, saving model to best_model1.hdf5
# 174/214 [=======================>......] - ETA: 21s - loss: 0.3275 - accuracy: 0.8741 - auroc: 0.7724
# Epoch 00001: accuracy improved from 0.87410 to 0.87430, saving model to best_model1.hdf5
# 175/214 [=======================>......] - ETA: 21s - loss: 0.3269 - accuracy: 0.8743 - auroc: 0.7732
# Epoch 00001: accuracy improved from 0.87430 to 0.87436, saving model to best_model1.hdf5
# 176/214 [=======================>......] - ETA: 20s - loss: 0.3264 - accuracy: 0.8744 - auroc: 0.7739
# Epoch 00001: accuracy improved from 0.87436 to 0.87456, saving model to best_model1.hdf5
# 177/214 [=======================>......] - ETA: 19s - loss: 0.3257 - accuracy: 0.8746 - auroc: 0.7749
# Epoch 00001: accuracy improved from 0.87456 to 0.87476, saving model to best_model1.hdf5
# 178/214 [=======================>......] - ETA: 19s - loss: 0.3250 - accuracy: 0.8748 - auroc: 0.7758
# Epoch 00001: accuracy improved from 0.87476 to 0.87508, saving model to best_model1.hdf5
# 179/214 [========================>.....] - ETA: 18s - loss: 0.3241 - accuracy: 0.8751 - auroc: 0.7768
# Epoch 00001: accuracy improved from 0.87508 to 0.87535, saving model to best_model1.hdf5
# 180/214 [========================>.....] - ETA: 18s - loss: 0.3234 - accuracy: 0.8754 - auroc: 0.7777
# Epoch 00001: accuracy improved from 0.87535 to 0.87556, saving model to best_model1.hdf5
# 181/214 [========================>.....] - ETA: 17s - loss: 0.3229 - accuracy: 0.8756 - auroc: 0.7784
# Epoch 00001: accuracy improved from 0.87556 to 0.87562, saving model to best_model1.hdf5
# 182/214 [========================>.....] - ETA: 17s - loss: 0.3225 - accuracy: 0.8756 - auroc: 0.7790
# Epoch 00001: accuracy improved from 0.87562 to 0.87583, saving model to best_model1.hdf5
# 183/214 [========================>.....] - ETA: 16s - loss: 0.3221 - accuracy: 0.8758 - auroc: 0.7797
# Epoch 00001: accuracy improved from 0.87583 to 0.87596, saving model to best_model1.hdf5
# 184/214 [========================>.....] - ETA: 16s - loss: 0.3217 - accuracy: 0.8760 - auroc: 0.7804
# Epoch 00001: accuracy improved from 0.87596 to 0.87629, saving model to best_model1.hdf5
# 185/214 [========================>.....] - ETA: 15s - loss: 0.3210 - accuracy: 0.8763 - auroc: 0.7812
# Epoch 00001: accuracy improved from 0.87629 to 0.87647, saving model to best_model1.hdf5
# 186/214 [=========================>....] - ETA: 15s - loss: 0.3203 - accuracy: 0.8765 - auroc: 0.7819
# Epoch 00001: accuracy improved from 0.87647 to 0.87672, saving model to best_model1.hdf5
# 187/214 [=========================>....] - ETA: 14s - loss: 0.3195 - accuracy: 0.8767 - auroc: 0.7829
# Epoch 00001: accuracy improved from 0.87672 to 0.87706, saving model to best_model1.hdf5
# 188/214 [=========================>....] - ETA: 14s - loss: 0.3188 - accuracy: 0.8771 - auroc: 0.7836
# Epoch 00001: accuracy improved from 0.87706 to 0.87721, saving model to best_model1.hdf5
# 189/214 [=========================>....] - ETA: 13s - loss: 0.3184 - accuracy: 0.8772 - auroc: 0.7844
# Epoch 00001: accuracy improved from 0.87721 to 0.87739, saving model to best_model1.hdf5
# 190/214 [=========================>....] - ETA: 13s - loss: 0.3179 - accuracy: 0.8774 - auroc: 0.7851
# Epoch 00001: accuracy improved from 0.87739 to 0.87766, saving model to best_model1.hdf5
# 191/214 [=========================>....] - ETA: 12s - loss: 0.3172 - accuracy: 0.8777 - auroc: 0.7858
# Epoch 00001: accuracy improved from 0.87766 to 0.87790, saving model to best_model1.hdf5
# 192/214 [=========================>....] - ETA: 12s - loss: 0.3165 - accuracy: 0.8779 - auroc: 0.7865
# Epoch 00001: accuracy improved from 0.87790 to 0.87812, saving model to best_model1.hdf5
# 193/214 [==========================>...] - ETA: 11s - loss: 0.3159 - accuracy: 0.8781 - auroc: 0.7874
# Epoch 00001: accuracy improved from 0.87812 to 0.87821, saving model to best_model1.hdf5
# 194/214 [==========================>...] - ETA: 11s - loss: 0.3155 - accuracy: 0.8782 - auroc: 0.7880
# Epoch 00001: accuracy improved from 0.87821 to 0.87838, saving model to best_model1.hdf5
# 195/214 [==========================>...] - ETA: 10s - loss: 0.3149 - accuracy: 0.8784 - auroc: 0.7888
# Epoch 00001: accuracy improved from 0.87838 to 0.87854, saving model to best_model1.hdf5
# 196/214 [==========================>...] - ETA: 9s - loss: 0.3145 - accuracy: 0.8785 - auroc: 0.7893
# Epoch 00001: accuracy improved from 0.87854 to 0.87865, saving model to best_model1.hdf5
# 197/214 [==========================>...] - ETA: 9s - loss: 0.3142 - accuracy: 0.8786 - auroc: 0.7899
# Epoch 00001: accuracy improved from 0.87865 to 0.87865, saving model to best_model1.hdf5
# 198/214 [==========================>...] - ETA: 8s - loss: 0.3140 - accuracy: 0.8787 - auroc: 0.7906
# Epoch 00001: accuracy improved from 0.87865 to 0.87881, saving model to best_model1.hdf5
# 199/214 [==========================>...] - ETA: 8s - loss: 0.3135 - accuracy: 0.8788 - auroc: 0.7913
# Epoch 00001: accuracy improved from 0.87881 to 0.87900, saving model to best_model1.hdf5
# 200/214 [===========================>..] - ETA: 7s - loss: 0.3129 - accuracy: 0.8790 - auroc: 0.7920
# Epoch 00001: accuracy improved from 0.87900 to 0.87925, saving model to best_model1.hdf5
# 201/214 [===========================>..] - ETA: 7s - loss: 0.3123 - accuracy: 0.8793 - auroc: 0.7928
# Epoch 00001: accuracy improved from 0.87925 to 0.87952, saving model to best_model1.hdf5
# 202/214 [===========================>..] - ETA: 6s - loss: 0.3116 - accuracy: 0.8795 - auroc: 0.7936
# Epoch 00001: accuracy improved from 0.87952 to 0.87979, saving model to best_model1.hdf5
# 203/214 [===========================>..] - ETA: 6s - loss: 0.3110 - accuracy: 0.8798 - auroc: 0.7943
# Epoch 00001: accuracy improved from 0.87979 to 0.88000, saving model to best_model1.hdf5
# 204/214 [===========================>..] - ETA: 5s - loss: 0.3103 - accuracy: 0.8800 - auroc: 0.7951
# Epoch 00001: accuracy improved from 0.88000 to 0.88005, saving model to best_model1.hdf5
# 205/214 [===========================>..] - ETA: 5s - loss: 0.3099 - accuracy: 0.8800 - auroc: 0.7958
# Epoch 00001: accuracy improved from 0.88005 to 0.88029, saving model to best_model1.hdf5
# 206/214 [===========================>..] - ETA: 4s - loss: 0.3093 - accuracy: 0.8803 - auroc: 0.7965
# Epoch 00001: accuracy improved from 0.88029 to 0.88050, saving model to best_model1.hdf5
# 207/214 [============================>.] - ETA: 3s - loss: 0.3087 - accuracy: 0.8805 - auroc: 0.7973
# Epoch 00001: accuracy improved from 0.88050 to 0.88069, saving model to best_model1.hdf5
# 208/214 [============================>.] - ETA: 3s - loss: 0.3083 - accuracy: 0.8807 - auroc: 0.7980
# Epoch 00001: accuracy improved from 0.88069 to 0.88078, saving model to best_model1.hdf5
# 209/214 [============================>.] - ETA: 2s - loss: 0.3081 - accuracy: 0.8808 - auroc: 0.7985
# Epoch 00001: accuracy improved from 0.88078 to 0.88097, saving model to best_model1.hdf5
# 210/214 [============================>.] - ETA: 2s - loss: 0.3075 - accuracy: 0.8810 - auroc: 0.7991
# Epoch 00001: accuracy improved from 0.88097 to 0.88125, saving model to best_model1.hdf5
# 211/214 [============================>.] - ETA: 1s - loss: 0.3069 - accuracy: 0.8812 - auroc: 0.7998
# Epoch 00001: accuracy improved from 0.88125 to 0.88135, saving model to best_model1.hdf5
# 212/214 [============================>.] - ETA: 1s - loss: 0.3065 - accuracy: 0.8814 - auroc: 0.8003
# Epoch 00001: accuracy improved from 0.88135 to 0.88152, saving model to best_model1.hdf5
# 213/214 [============================>.] - ETA: 0s - loss: 0.3060 - accuracy: 0.8815 - auroc: 0.8009
# Epoch 00001: accuracy improved from 0.88152 to 0.88156, saving model to best_model1.hdf5
# 214/214 [==============================] - 122s 569ms/step - loss: 0.3058 - accuracy: 0.8816 - auroc: 0.8016 - val_loss: 1.1835 - val_accuracy: 0.3313 - val_auroc: 0.9094 - lr: 0.0010
# Epoch 2/10
#
# Epoch 00002: accuracy improved from 0.88156 to 0.90000, saving model to best_model1.hdf5
#   1/214 [..............................] - ETA: 2:40 - loss: 0.2123 - accuracy: 0.9000 - auroc: 0.9579
# Epoch 00002: accuracy improved from 0.90000 to 0.90667, saving model to best_model1.hdf5
#   2/214 [..............................] - ETA: 2:16 - loss: 0.2064 - accuracy: 0.9067 - auroc: 0.9477
# Epoch 00002: accuracy improved from 0.90667 to 0.91111, saving model to best_model1.hdf5
#   3/214 [..............................] - ETA: 2:06 - loss: 0.2097 - accuracy: 0.9111 - auroc: 0.9404
# Epoch 00002: accuracy improved from 0.91111 to 0.91500, saving model to best_model1.hdf5
#   4/214 [..............................] - ETA: 2:02 - loss: 0.2000 - accuracy: 0.9150 - auroc: 0.9395
# Epoch 00002: accuracy improved from 0.91500 to 0.92000, saving model to best_model1.hdf5
#   5/214 [..............................] - ETA: 2:03 - loss: 0.1942 - accuracy: 0.9200 - auroc: 0.9408
# Epoch 00002: accuracy did not improve from 0.92000
#
# Epoch 00002: accuracy did not improve from 0.92000
#
# Epoch 00002: accuracy did not improve from 0.92000
#
# Epoch 00002: accuracy improved from 0.92000 to 0.92148, saving model to best_model1.hdf5
#   9/214 [>.............................] - ETA: 1:20 - loss: 0.1957 - accuracy: 0.9215 - auroc: 0.9368
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#  16/214 [=>............................] - ETA: 42s - loss: 0.1940 - accuracy: 0.9181 - auroc: 0.9387
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#  24/214 [==>...........................] - ETA: 26s - loss: 0.1986 - accuracy: 0.9172 - auroc: 0.9370
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#  31/214 [===>..........................] - ETA: 20s - loss: 0.1983 - accuracy: 0.9167 - auroc: 0.9379
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#  37/214 [====>.........................] - ETA: 16s - loss: 0.2002 - accuracy: 0.9168 - auroc: 0.9357
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#  44/214 [=====>........................] - ETA: 13s - loss: 0.2007 - accuracy: 0.9159 - auroc: 0.9354
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#  52/214 [======>.......................] - ETA: 10s - loss: 0.1985 - accuracy: 0.9178 - auroc: 0.9362
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#  61/214 [=======>......................] - ETA: 8s - loss: 0.1982 - accuracy: 0.9178 - auroc: 0.9365
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#  66/214 [========>.....................] - ETA: 8s - loss: 0.2006 - accuracy: 0.9171 - auroc: 0.9355
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#  75/214 [=========>....................] - ETA: 6s - loss: 0.2023 - accuracy: 0.9156 - auroc: 0.9350
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#  83/214 [==========>...................] - ETA: 5s - loss: 0.2021 - accuracy: 0.9159 - auroc: 0.9356
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#  93/214 [============>.................] - ETA: 4s - loss: 0.2014 - accuracy: 0.9168 - auroc: 0.9363
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
# 101/214 [=============>................] - ETA: 4s - loss: 0.2004 - accuracy: 0.9172 - auroc: 0.9369
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
# 109/214 [==============>...............] - ETA: 3s - loss: 0.1996 - accuracy: 0.9172 - auroc: 0.9373
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
# 116/214 [===============>..............] - ETA: 3s - loss: 0.1991 - accuracy: 0.9176 - auroc: 0.9379
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
# 122/214 [================>.............] - ETA: 2s - loss: 0.1979 - accuracy: 0.9183 - auroc: 0.9387
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
# 129/214 [=================>............] - ETA: 2s - loss: 0.1968 - accuracy: 0.9187 - auroc: 0.9390
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
# 135/214 [=================>............] - ETA: 2s - loss: 0.1967 - accuracy: 0.9186 - auroc: 0.9391
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
# 142/214 [==================>...........] - ETA: 2s - loss: 0.1967 - accuracy: 0.9186 - auroc: 0.9391
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
# 151/214 [====================>.........] - ETA: 1s - loss: 0.1962 - accuracy: 0.9190 - auroc: 0.9393
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
# 159/214 [=====================>........] - ETA: 1s - loss: 0.1960 - accuracy: 0.9192 - auroc: 0.9394
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# Epoch 00002: accuracy did not improve from 0.92148
#
# ...
#
# Epoch 00009: accuracy did not improve from 0.94778
#
# Epoch 00009: accuracy did not improve from 0.94778
#
# Epoch 00009: accuracy did not improve from 0.94778
#
# Epoch 00009: accuracy did not improve from 0.94778
#
# Epoch 00009: accuracy did not improve from 0.94778
# 198/214 [==========================>...] - ETA: 0s - loss: 0.1602 - accuracy: 0.9347 - auroc: 0.9613
# Epoch 00009: accuracy did not improve from 0.94778
#
# Epoch 00009: accuracy did not improve from 0.94778
#
# Epoch 00009: accuracy did not improve from 0.94778
#
# Epoch 00009: accuracy did not improve from 0.94778
#
# Epoch 00009: accuracy did not improve from 0.94778
#
# Epoch 00009: accuracy did not improve from 0.94778
#
# Epoch 00009: accuracy did not improve from 0.94778
#
# Epoch 00009: accuracy did not improve from 0.94778
# 206/214 [===========================>..] - ETA: 0s - loss: 0.1595 - accuracy: 0.9350 - auroc: 0.9615
# Epoch 00009: accuracy did not improve from 0.94778
#
# Epoch 00009: accuracy did not improve from 0.94778
#
# Epoch 00009: accuracy did not improve from 0.94778
#
# Epoch 00009: accuracy did not improve from 0.94778
#
# Epoch 00009: accuracy did not improve from 0.94778
#
# Epoch 00009: accuracy did not improve from 0.94778
#
# Epoch 00009: accuracy did not improve from 0.94778
# 213/214 [============================>.] - ETA: 0s - loss: 0.1603 - accuracy: 0.9349 - auroc: 0.9611
# Epoch 00009: accuracy did not improve from 0.94778
# 214/214 [==============================] - 2s 9ms/step - loss: 0.1603 - accuracy: 0.9350 - auroc: 0.9611 - val_loss: 0.2681 - val_accuracy: 0.9070 - val_auroc: 0.9585 - lr: 0.0010
# Epoch 10/10
#
# Epoch 00010: accuracy did not improve from 0.94778
#   1/214 [..............................] - ETA: 2s - loss: 0.1703 - accuracy: 0.9467 - auroc: 0.9549
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#   7/214 [..............................] - ETA: 1s - loss: 0.1625 - accuracy: 0.9319 - auroc: 0.9617
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#  13/214 [>.............................] - ETA: 1s - loss: 0.1632 - accuracy: 0.9295 - auroc: 0.9587
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#  19/214 [=>............................] - ETA: 1s - loss: 0.1618 - accuracy: 0.9307 - auroc: 0.9613
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#  25/214 [==>...........................] - ETA: 1s - loss: 0.1608 - accuracy: 0.9299 - auroc: 0.9619
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#  31/214 [===>..........................] - ETA: 1s - loss: 0.1589 - accuracy: 0.9317 - auroc: 0.9635
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#  37/214 [====>.........................] - ETA: 1s - loss: 0.1576 - accuracy: 0.9327 - auroc: 0.9639
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#  44/214 [=====>........................] - ETA: 1s - loss: 0.1598 - accuracy: 0.9317 - auroc: 0.9633
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#  51/214 [======>.......................] - ETA: 1s - loss: 0.1599 - accuracy: 0.9325 - auroc: 0.9623
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#  58/214 [=======>......................] - ETA: 1s - loss: 0.1610 - accuracy: 0.9330 - auroc: 0.9616
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#  64/214 [=======>......................] - ETA: 1s - loss: 0.1598 - accuracy: 0.9341 - auroc: 0.9619
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#  71/214 [========>.....................] - ETA: 1s - loss: 0.1586 - accuracy: 0.9348 - auroc: 0.9624
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#  79/214 [==========>...................] - ETA: 1s - loss: 0.1582 - accuracy: 0.9347 - auroc: 0.9625
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#  87/214 [===========>..................] - ETA: 1s - loss: 0.1589 - accuracy: 0.9349 - auroc: 0.9617
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#  95/214 [============>.................] - ETA: 0s - loss: 0.1577 - accuracy: 0.9351 - auroc: 0.9623
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
# 102/214 [=============>................] - ETA: 0s - loss: 0.1574 - accuracy: 0.9356 - auroc: 0.9625
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
# 109/214 [==============>...............] - ETA: 0s - loss: 0.1580 - accuracy: 0.9353 - auroc: 0.9624
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
# 116/214 [===============>..............] - ETA: 0s - loss: 0.1578 - accuracy: 0.9353 - auroc: 0.9626
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
# 123/214 [================>.............] - ETA: 0s - loss: 0.1584 - accuracy: 0.9352 - auroc: 0.9622
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
# 129/214 [=================>............] - ETA: 0s - loss: 0.1580 - accuracy: 0.9351 - auroc: 0.9622
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
# 135/214 [=================>............] - ETA: 0s - loss: 0.1589 - accuracy: 0.9347 - auroc: 0.9618
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
# 142/214 [==================>...........] - ETA: 0s - loss: 0.1583 - accuracy: 0.9352 - auroc: 0.9619
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
# 149/214 [===================>..........] - ETA: 0s - loss: 0.1583 - accuracy: 0.9350 - auroc: 0.9620
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
# 156/214 [====================>.........] - ETA: 0s - loss: 0.1583 - accuracy: 0.9352 - auroc: 0.9622
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
# 164/214 [=====================>........] - ETA: 0s - loss: 0.1586 - accuracy: 0.9353 - auroc: 0.9619
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
# 173/214 [=======================>......] - ETA: 0s - loss: 0.1586 - accuracy: 0.9352 - auroc: 0.9619
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
# 180/214 [========================>.....] - ETA: 0s - loss: 0.1585 - accuracy: 0.9353 - auroc: 0.9618
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
# 188/214 [=========================>....] - ETA: 0s - loss: 0.1585 - accuracy: 0.9351 - auroc: 0.9619
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
# 196/214 [==========================>...] - ETA: 0s - loss: 0.1584 - accuracy: 0.9352 - auroc: 0.9620
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
# 203/214 [===========================>..] - ETA: 0s - loss: 0.1586 - accuracy: 0.9351 - auroc: 0.9621
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
# 211/214 [============================>.] - ETA: 0s - loss: 0.1582 - accuracy: 0.9355 - auroc: 0.9622
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
#
# Epoch 00010: accuracy did not improve from 0.94778
# 214/214 [==============================] - 2s 9ms/step - loss: 0.1583 - accuracy: 0.9354 - auroc: 0.9622 - val_loss: 0.1911 - val_accuracy: 0.9306 - val_auroc: 0.9544 - lr: 0.0010

# %%
# !pip install pydot graphviz
import pydot
import graphviz
tf.keras.utils.plot_model(
    model, to_file='model1.png', show_shapes=False, show_layer_names=True,
    rankdir='TB', expand_nested=False, dpi=96
)
